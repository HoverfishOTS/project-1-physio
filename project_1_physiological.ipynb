# %% [markdown]
# # Track 1: Physiological Signals (Wearable Tech)
#
# **Program Context:** Multimodal Emotion Recognition Summer Research Program
#
# **Colab Instructions:** To run this notebook in Google Colab, click the badge in the README or upload the file to your Google Drive, right-click, and select 'Open with Google Colaboratory'.
#
# Fill in every cell marked `TODO`. Run cells top to bottom.

# %% [markdown]
# ## 0. Install and import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import neurokit2 as nk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## 1. Week 2 -- Data Acquisition
#
# Load the WESAD dataset into a pandas DataFrame. The dataset is provided as pickled files (`.pkl`). Extract the raw PPG, EDA, and corresponding emotion labels.

# %%
# TODO: load WESAD dataset pkl file and extract signals and labels.
def load_wesad_data(file_path):
    pass

df = None

# %% [markdown]
# ## 2. Week 3 -- Signal Processing
#
# Clean the physiological signals using the `neurokit2` library. Separate the EDA signal into its tonic and phasic components and filter the baseline wander from the PPG signal.

# %%
# TODO: implement signal cleaning using nk.eda_process and nk.ppg_clean.
def preprocess_signals(ppg_raw, eda_raw, sampling_rate=700):
    pass

cleaned_signals = None

# %% [markdown]
# ## 3. Week 4 -- Feature Extraction
#
# Extract statistical features from the cleaned signals using rolling time windows (e.g., 60 seconds). Calculate metrics such as mean heart rate, heart rate variability, and the number of EDA peaks.

# %%
# TODO: extract features and return a structured DataFrame.
def extract_features(cleaned_signals):
    pass

features_df = None

# %% [markdown]
# ## 4. Week 6 -- Model Training
#
# Split the extracted feature dataset into training and testing sets. Initialize and train a baseline machine learning classifier to predict the target emotion label.

# %%
# TODO: split data and train a classifier (e.g., RandomForestClassifier).
X_train, X_test, y_train, y_test = None, None, None, None
model = None

# %% [markdown]
# ## 5. Week 7 -- Evaluation
#
# Generate predictions on the test set. Evaluate the classifier's performance using precision, recall, F1-score, and plot a confusion matrix to visualize the results.

# %%
# TODO: predict on X_test and generate classification_report and confusion_matrix.
predictions = None

# %% [markdown]
# ## 6. Week 9 -- Synthesis and Ethics
#
# Interpret your evaluation metrics. Which physiological features (e.g., HRV, EDA peaks) were most predictive of stress versus a neutral state? Draft a discussion on the ethical implications of biometric data collection, focusing specifically on user privacy and consent in real-world wearable tech applications.

# %% [markdown]
# *TODO: Write your week 9 analysis here.*

# %% [markdown]
# ## 7. Week 10 -- Final Deliverables
#
# Prepare your final research paper or poster and your slide deck for the final presentation. Ensure all code cells above are clean, commented appropriately, and that your data pipeline is fully documented for reproducibility.
